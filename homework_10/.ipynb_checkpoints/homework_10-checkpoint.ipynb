# %% [markdown]
# # Домашнее задание к лекции "Библиотека Pandas"

# %%
import pandas as pd

# %% [markdown]
# ## Задание 1
#
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')

# %%
ratings = ratings.merge(movies, on='movieId', how='left')
ratings[ ratings['rating'] == 5.0 ].value_counts('title').head(5)
# Out:
# title
# Shawshank Redemption, The (1994)             153
# Pulp Fiction (1994)                          123
# Forrest Gump (1994)                          116
# Matrix, The (1999)                           109
# Star Wars: Episode IV - A New Hope (1977)    104
# dtype: int64

# %% [markdown]
# ## Задание 2
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head(10)
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1
# 5  Belgium  2011      25.0         1
# 6  Belgium  2010      22.0         1
# 7  Belgium  2009      45.0         1
# 8  Czechia  1998       1.0         1
# 9  Czechia  1995       7.0         1

# %%
power['country'].unique()
power[
     ((power['country'] == 'Latvia') | (power['country'] == 'Lithuania') | (power['country'] == 'Estonia')) &  # Baltic states
     ((power['category'] == 4) | (power['category'] == 12) | (power['category'] == 21)) &  # Categories
     ((power['year'] >= 2005) & (power['year'] <= 2010)) &  # Years
     (power['quantity'] > 0)  # Positive values
     ]['quantity'].sum()
# by using ['quantity'] we turn Dataframe into Series => we get single value as a result of the .sum()
# Out:
# 240580.0

# %% [markdown]
# ## Задание 3
#
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц:
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
currencies = pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', attrs = {'class' : 'quote_list'}, encoding='utf-8')
currencies[0]
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB      1046422      -              1045488
# 1          NaN            EUR/RUB       873860      -               871080
# 2          NaN            USD/RUB       765265      -               764720
# 3          NaN            JPY/RUB        06686      -                06694
# 4          NaN            CNY/RUB       120510      -               120378
# 5          NaN            CHF/RUB       837768      -               837085
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        11419      -                11417
# 8          NaN            EUR/GBP        08354      -                08350
# 9          NaN            EUR/JPY      1307320      -              1304250
# 10         NaN            EUR/CHF        10434      -                10418
# 11         NaN         Доллар США  Предложение  Спрос  Предыдущее закрытие
# 12         NaN            USD/EUR        08756      -                08759
# 13         NaN            USD/GBP        07314      -                07315
# 14         NaN            USD/JPY      1144830      -              1142350
# 15         NaN            USD/CHF        09136      -                09137
# 16         NaN      Японская иена  Предложение  Спрос  Предыдущее закрытие
# 17         NaN    JPY/EUR (100:1)        07600      -                07700
# 18         NaN            JPY/GBP        00064      -                00064
# 19         NaN            JPY/USD        00087      -                00088
# 20         NaN    JPY/CHF (100:1)        08000      -                08000
# 21         NaN    Фунт стерлингов  Предложение  Спрос  Предыдущее закрытие
# 22         NaN            GBP/USD        13671      -                13672
# 23         NaN            GBP/JPY      1565253      -              1561832
# 24         NaN            GBP/EUR        11972      -                11982
# 25         NaN            GBP/CHF        12491      -                12497
# 26         NaN  Швейцарский франк  Предложение  Спрос  Предыдущее закрытие
# 27         NaN            GBP/CHF        12491      -                12497
# 28         NaN            EUR/CHF        10434      -                10418
# 29         NaN    JPY/CHF (100:1)        08000      -                08000
# 30         NaN            USD/CHF        09136      -                09137
# 31         NaN  Украинская гривна  Предложение  Спрос  Предыдущее закрытие
# 32         NaN            EUR/UAH       321289      -               314805
# 33         NaN            USD/UAH       281474      -               275731
# 34         NaN            CHF/UAH       307824      -               301824
# 35         NaN            GBP/UAH       384831      -               376967
#
#          %  Абсолютное значение     Время
# 0    0,09%                00934  14:33:00
# 1    0,32%                02780  14:33:00
# 2    0,07%                00545  14:33:00
# 3   -0,13%               -00008  14:33:00
# 4    0,11%                00131  14:40:00
# 5    0,08%                00684  14:33:00
# 6        %  Абсолютное значение     Время
# 7    0,02%                00002  14:33:00
# 8    0,05%                00004  14:33:00
# 9    0,24%                03070  14:33:00
# 10   0,15%                00016  14:33:00
# 11       %  Абсолютное значение     Время
# 12  -0,03%               -00003  14:33:00
# 13   0,00%                00000  14:33:00
# 14   0,22%                02480  14:33:00
# 15  -0,01%               -00001  14:33:00
# 16       %  Абсолютное значение     Время
# 17  -0,24%                00000  14:33:00
# 18  -0,22%                00000  14:33:00
# 19  -0,21%                00000  14:33:00
# 20  -0,23%                00000  14:33:00
# 21       %  Абсолютное значение     Время
# 22   0,00%               -00001  14:40:00
# 23   0,22%                03420  14:33:00
# 24  -0,08%               -00010  14:33:00
# 25  -0,05%               -00006  14:33:00
# 26       %  Абсолютное значение     Время
# 27  -0,05%               -00006  14:33:00
# 28   0,15%                00016  14:33:00
# 29  -0,23%                00000  14:33:00
# 30  -0,01%               -00001  14:33:00
# 31       %  Абсолютное значение     Время
# 32   2,06%                06484  14:40:00
# 33   2,08%                05743  14:33:00
# 34   1,99%                05999  14:40:00
# 35   2,09%                07864  14:33:00
